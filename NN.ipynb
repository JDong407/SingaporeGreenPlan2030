# %%
import pandas as pd
df = pd.read_csv('/Users/melissalian/Desktop/untitled folder/preprocessdata.csv')

# %%
df
# Out:
#       Daily Rainfall Total (mm)  Highest 30 Min Rainfall (mm)  \
# 0                     -1.234920                     -1.496323
# 1                     -1.069239                     -1.159290
# 2                     -1.387421                     -1.680647
# 3                     -1.087096                     -1.177888
# 4                     -0.918836                     -1.590758
# ...                         ...                           ...
# 1048                  -0.462914                     -0.828705
# 1049                  -0.110767                      0.133875
# 1050                  -0.425154                     -0.115314
# 1051                  -0.375604                     -0.250479
# 1052                   0.039106                     -0.261068
#
#       Highest 60 Min Rainfall (mm)  Highest 120 Min Rainfall (mm)  \
# 0                        -1.475633                      -1.434619
# 1                        -1.207874                      -1.200211
# ...

# %%
df_encoded = pd.get_dummies(df, columns=['Region'])

# %%
train = df_encoded[(df_encoded['Year'] < 2023)]
test = df_encoded[(df_encoded['Year'] ==2023)]

# %%
train
# Out:
#      Daily Rainfall Total (mm)  Highest 30 Min Rainfall (mm)  \
# 0                    -1.234920                     -1.496323
# 1                    -1.069239                     -1.159290
# 2                    -1.387421                     -1.680647
# 3                    -1.087096                     -1.177888
# 4                    -0.918836                     -1.590758
# ..                         ...                           ...
# 967                   0.228618                      0.338203
# 968                   1.196727                      1.176590
# 969                  -0.112674                     -0.038547
# 970                   1.202018                      1.578302
# 971                   0.247948                      0.424722
#
#      Highest 60 Min Rainfall (mm)  Highest 120 Min Rainfall (mm)  \
# 0                       -1.475633                      -1.434619
# 1                       -1.207874                      -1.200211
# ...

# %%
test
# Out:
#       Daily Rainfall Total (mm)  Highest 30 Min Rainfall (mm)  \
# 972                   -0.133108                     -0.759774
# 973                    0.215536                     -0.536265
# 974                    0.599622                     -0.314420
# 975                    0.501639                     -0.165471
# 976                    0.150258                     -0.395860
# ...                         ...                           ...
# 1048                  -0.462914                     -0.828705
# 1049                  -0.110767                      0.133875
# 1050                  -0.425154                     -0.115314
# 1051                  -0.375604                     -0.250479
# 1052                   0.039106                     -0.261068
#
#       Highest 60 Min Rainfall (mm)  Highest 120 Min Rainfall (mm)  \
# 972                      -0.684555                      -0.445182
# 973                      -0.342293                      -0.059846
# ...

# %%
X_train = train.drop(["Mean Temperature (°C)"], axis=1)
y_train = train["Mean Temperature (°C)"]

X_test = test.drop(["Mean Temperature (°C)"], axis=1)
y_test = test["Mean Temperature (°C)"]

# %%
X_test
# Out:
#       Daily Rainfall Total (mm)  Highest 30 Min Rainfall (mm)  \
# 972                   -0.133108                     -0.759774
# 973                    0.215536                     -0.536265
# 974                    0.599622                     -0.314420
# 975                    0.501639                     -0.165471
# 976                    0.150258                     -0.395860
# ...                         ...                           ...
# 1048                  -0.462914                     -0.828705
# 1049                  -0.110767                      0.133875
# 1050                  -0.425154                     -0.115314
# 1051                  -0.375604                     -0.250479
# 1052                   0.039106                     -0.261068
#
#       Highest 60 Min Rainfall (mm)  Highest 120 Min Rainfall (mm)  \
# 972                      -0.684555                      -0.445182
# 973                      -0.342293                      -0.059846
# ...

# %% [markdown]
# # Basic Model

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

# Create and train an MLP regression model
mlp_regressor = MLPRegressor(random_state=42)
mlp_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = mlp_regressor.predict(X_test)

# Calculate the mean squared error to evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.07729219172111186

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
import numpy as np

# Define the MLPRegressor and parameter grid for the grid search
param_grid = {
    'hidden_layer_sizes': [(50), (50,50), (50,100)],
    'alpha': [0.001, 0.0001, 0.01],
    'activation': ["logistic", "relu", "Tanh"],
    'learning_rate_init': [0.001, 0.0001, 0.00001],
    'max_iter':[200, 300, 700],
    'early_stopping': [True],
    'validation_fraction': [0.1],  # Fraction of training data to use for validation
    'n_iter_no_change': [10] 
    }



mlp_regressor = MLPRegressor(random_state=42)

# Create the GridSearchCV object
grid_search = GridSearchCV(mlp_regressor, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, y_train)

# Get the best model and its hyperparameters
best_mlp = grid_search.best_estimator_
best_params = grid_search.best_params_

# Display the best model and hyperparameters
print("Best MLP Regressor:", best_mlp)
print("Best Hyperparameters:", best_params)
# Out:
# /Users/melissalian/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/melissalian/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/melissalian/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/melissalian/anaconda3/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# ...

# %%
# Make predictions on the test data
y_pred = best_mlp.predict(X_test)

# Evaluate the model on the test data
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error on Test Data:", mse)
# Out:
# Mean Squared Error on Test Data: 0.04860180857996303
